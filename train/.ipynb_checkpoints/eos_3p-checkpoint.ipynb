# %% [markdown]
# ## Predict 3P EoS

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
plt.rcParams.update({'font.size': 20})
# Out:
# 2022-07-11 12:26:45.006778: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# ### 1. Load data from file and prepare for training
#
# Load the EoS and the $M-R$ curves from processed data files.

# %%
# Load the un-normalized data.
R = np.loadtxt('../data/m-r_3p.txt')
P = np.loadtxt('../data/eos_3p.txt')

# %% [markdown]
# Next, normalize the data and perform a train-test-validation split as 80-15-5.

# %%
# Normalize the data
r = (R - np.min(R)) / (np.max(R) - np.min(R))
p = (P - np.min(P)) / (np.max(P) - np.min(P))

# Perform train-test-validation split: 80-15-5
x_tr, x_tv, y_tr, y_tv = train_test_split(r, p, test_size=0.2, random_state=41)
x_ts, x_vl, y_ts, y_vl = train_test_split(x_tv, y_tv, test_size=0.25, random_state=41)

# %% [markdown]
# ### 2. Build DNN Model or load model from file
#
# Construct a deep-learning neural network (DNN). The architecture and the hyperparameters of the DNN are chosen using `keras_tuner` to optimize for performance and accuracy (see `search/random_search_3p.ipynb`).

# %%
# Load model from file
#model = load_model("../output/model_3p.h5")

# Build model from scratch
model = keras.Sequential([
    layers.Dense(194, input_shape=(97,), activation='relu'),
    layers.Dense(776, activation='relu'),
    layers.Dense(582, activation='relu'),
    layers.Dense(97, activation='linear')])

model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 194)               19012
# _________________________________________________________________
# dense_9 (Dense)              (None, 776)               151320
# _________________________________________________________________
# dense_10 (Dense)             (None, 582)               452214
# _________________________________________________________________
# dense_11 (Dense)             (None, 97)                56551
# =================================================================
# Total params: 679,097
# Trainable params: 679,097
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. Set up callbacks and training parameters
#
# Set values of training parameters: batch size and number of epochs. Also, create optional callbacks such as early stopping and saving weights with checkpointings.

# %%
batch_size = 256
num_epochs = 5000

# Set up a callback to stop early if given criteria is satisfied
stop_early = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=1.0e-10, patience=40)

# Setup checkpointing
ckpt_path = "../ckpts/eos_3p.ckpt"
ckpt_dir = os.path.dirname(ckpt_path)

# Set up another callback that saves the model's weights
save_weights = tf.keras.callbacks.ModelCheckpoint(filepath=ckpt_path, save_weights_only=True, verbose=0)

# %% [markdown]
# ### 4. Fit model and save training history
#
# Train the DNN using training and testing data. Note that we still have unobserved validation data left to be used later for further testing and predicting EoS.

# %%
training = model.fit(x=x_tr, y=y_tr, batch_size=batch_size, validation_data=(x_ts, y_ts), \
                    epochs=num_epochs, callbacks=[stop_early, save_weights], verbose=2)
# Out:
# Epoch 1/5000
# 34/34 - 0s - loss: 0.0028 - val_loss: 4.8160e-04
# Epoch 2/5000
# 34/34 - 0s - loss: 4.9685e-04 - val_loss: 4.3296e-04
# Epoch 3/5000
# 34/34 - 0s - loss: 4.6450e-04 - val_loss: 4.0618e-04
# Epoch 4/5000
# 34/34 - 0s - loss: 4.4556e-04 - val_loss: 3.9644e-04
# Epoch 5/5000
# 34/34 - 0s - loss: 4.2606e-04 - val_loss: 3.5543e-04
# Epoch 6/5000
# 34/34 - 0s - loss: 4.1339e-04 - val_loss: 3.3735e-04
# Epoch 7/5000
# 34/34 - 0s - loss: 3.8482e-04 - val_loss: 4.3798e-04
# Epoch 8/5000
# 34/34 - 0s - loss: 4.2799e-04 - val_loss: 3.3608e-04
# Epoch 9/5000
# 34/34 - 0s - loss: 3.6340e-04 - val_loss: 3.1137e-04
# Epoch 10/5000
# 34/34 - 0s - loss: 3.5683e-04 - val_loss: 3.0290e-04
# Epoch 11/5000
# 34/34 - 0s - loss: 3.8060e-04 - val_loss: 3.1345e-04
# Epoch 12/5000
# 34/34 - 0s - loss: 3.5561e-04 - val_loss: 3.0020e-04
# Epoch 13/5000
# 34/34 - 0s - loss: 3.6140e-04 - val_loss: 3.1752e-04
# Epoch 14/5000
# 34/34 - 0s - loss: 3.9938e-04 - val_loss: 4.1129e-04
# Epoch 15/5000
# 34/34 - 0s - loss: 3.6125e-04 - val_loss: 2.9778e-04
# Epoch 16/5000
# 34/34 - 0s - loss: 3.2714e-04 - val_loss: 2.8970e-04
# Epoch 17/5000
# 34/34 - 0s - loss: 3.4142e-04 - val_loss: 2.8651e-04
# Epoch 18/5000
# 34/34 - 0s - loss: 3.2818e-04 - val_loss: 2.8760e-04
# Epoch 19/5000
# 34/34 - 0s - loss: 3.5384e-04 - val_loss: 2.9867e-04
# Epoch 20/5000
# 34/34 - 0s - loss: 3.3844e-04 - val_loss: 2.8528e-04
# Epoch 21/5000
# 34/34 - 0s - loss: 3.3198e-04 - val_loss: 2.7971e-04
# Epoch 22/5000
# 34/34 - 0s - loss: 3.1632e-04 - val_loss: 3.0236e-04
# Epoch 23/5000
# 34/34 - 0s - loss: 3.1821e-04 - val_loss: 3.1225e-04
# Epoch 24/5000
# 34/34 - 0s - loss: 3.2289e-04 - val_loss: 2.7643e-04
# Epoch 25/5000
# 34/34 - 0s - loss: 3.1245e-04 - val_loss: 2.7639e-04
# Epoch 26/5000
# 34/34 - 0s - loss: 3.3476e-04 - val_loss: 2.8520e-04
# Epoch 27/5000
# 34/34 - 0s - loss: 3.1191e-04 - val_loss: 2.6986e-04
# Epoch 28/5000
# 34/34 - 0s - loss: 3.2214e-04 - val_loss: 2.8963e-04
# Epoch 29/5000
# 34/34 - 0s - loss: 3.0636e-04 - val_loss: 2.7479e-04
# Epoch 30/5000
# 34/34 - 0s - loss: 3.0459e-04 - val_loss: 2.6453e-04
# Epoch 31/5000
# 34/34 - 0s - loss: 3.2455e-04 - val_loss: 2.9352e-04
# Epoch 32/5000
# 34/34 - 0s - loss: 3.2263e-04 - val_loss: 2.8891e-04
# Epoch 33/5000
# 34/34 - 0s - loss: 3.1684e-04 - val_loss: 2.7129e-04
# Epoch 34/5000
# 34/34 - 0s - loss: 3.0200e-04 - val_loss: 2.7025e-04
# Epoch 35/5000
# 34/34 - 0s - loss: 3.0450e-04 - val_loss: 3.1611e-04
# Epoch 36/5000
# 34/34 - 0s - loss: 3.0516e-04 - val_loss: 2.7140e-04
# Epoch 37/5000
# 34/34 - 0s - loss: 3.0548e-04 - val_loss: 2.8082e-04
# Epoch 38/5000
# 34/34 - 0s - loss: 3.1962e-04 - val_loss: 3.5125e-04
# Epoch 39/5000
# 34/34 - 0s - loss: 3.4827e-04 - val_loss: 2.7483e-04
# Epoch 40/5000
# 34/34 - 0s - loss: 3.0952e-04 - val_loss: 2.7660e-04
# Epoch 41/5000
# 34/34 - 0s - loss: 3.0023e-04 - val_loss: 2.6728e-04
# Epoch 42/5000
# 34/34 - 0s - loss: 2.8962e-04 - val_loss: 2.6199e-04
# Epoch 43/5000
# 34/34 - 0s - loss: 2.9282e-04 - val_loss: 2.5506e-04
# Epoch 44/5000
# 34/34 - 0s - loss: 3.0998e-04 - val_loss: 2.5393e-04
# Epoch 45/5000
# 34/34 - 0s - loss: 3.1438e-04 - val_loss: 2.6988e-04
# Epoch 46/5000
# 34/34 - 0s - loss: 3.0544e-04 - val_loss: 2.7391e-04
# Epoch 47/5000
# 34/34 - 0s - loss: 3.0527e-04 - val_loss: 3.1400e-04
# Epoch 48/5000
# 34/34 - 0s - loss: 3.0035e-04 - val_loss: 2.5533e-04
# Epoch 49/5000
# 34/34 - 0s - loss: 2.8388e-04 - val_loss: 2.5269e-04
# Epoch 50/5000
# 34/34 - 0s - loss: 2.7351e-04 - val_loss: 2.7691e-04
# Epoch 51/5000
# 34/34 - 0s - loss: 2.8964e-04 - val_loss: 2.5225e-04
# Epoch 52/5000
# 34/34 - 0s - loss: 2.7371e-04 - val_loss: 2.7790e-04
# Epoch 53/5000
# 34/34 - 0s - loss: 2.7988e-04 - val_loss: 2.7197e-04
# Epoch 54/5000
# 34/34 - 0s - loss: 2.9667e-04 - val_loss: 2.6402e-04
# Epoch 55/5000
# 34/34 - 0s - loss: 2.8414e-04 - val_loss: 2.7951e-04
# Epoch 56/5000
# 34/34 - 0s - loss: 2.8832e-04 - val_loss: 2.5658e-04
# Epoch 57/5000
# 34/34 - 0s - loss: 2.9736e-04 - val_loss: 2.6494e-04
# Epoch 58/5000
# 34/34 - 0s - loss: 2.9575e-04 - val_loss: 2.4349e-04
# Epoch 59/5000
# 34/34 - 0s - loss: 2.8537e-04 - val_loss: 2.5792e-04
# Epoch 60/5000
# 34/34 - 0s - loss: 2.7665e-04 - val_loss: 2.4803e-04
# Epoch 61/5000
# 34/34 - 0s - loss: 2.8966e-04 - val_loss: 2.4346e-04
# Epoch 62/5000
# 34/34 - 0s - loss: 2.7718e-04 - val_loss: 2.4878e-04
# Epoch 63/5000
# 34/34 - 0s - loss: 3.0504e-04 - val_loss: 2.8260e-04
# Epoch 64/5000
# 34/34 - 0s - loss: 2.8746e-04 - val_loss: 2.3813e-04
# Epoch 65/5000
# 34/34 - 0s - loss: 2.6462e-04 - val_loss: 2.4669e-04
# Epoch 66/5000
# 34/34 - 0s - loss: 2.7897e-04 - val_loss: 2.4227e-04
# Epoch 67/5000
# 34/34 - 0s - loss: 2.7398e-04 - val_loss: 2.3507e-04
# Epoch 68/5000
# 34/34 - 0s - loss: 2.9326e-04 - val_loss: 2.3987e-04
# Epoch 69/5000
# 34/34 - 0s - loss: 2.6595e-04 - val_loss: 2.3729e-04
# Epoch 70/5000
# 34/34 - 0s - loss: 3.0616e-04 - val_loss: 2.4573e-04
# Epoch 71/5000
# 34/34 - 0s - loss: 2.9036e-04 - val_loss: 3.1457e-04
# Epoch 72/5000
# 34/34 - 0s - loss: 2.8574e-04 - val_loss: 2.3931e-04
# Epoch 73/5000
# 34/34 - 0s - loss: 2.6208e-04 - val_loss: 2.3510e-04
# Epoch 74/5000
# 34/34 - 0s - loss: 2.7708e-04 - val_loss: 2.7921e-04
# Epoch 75/5000
# 34/34 - 0s - loss: 2.7210e-04 - val_loss: 2.5648e-04
# Epoch 76/5000
# 34/34 - 0s - loss: 2.6879e-04 - val_loss: 2.9176e-04
# Epoch 77/5000
# 34/34 - 0s - loss: 2.7291e-04 - val_loss: 2.5066e-04
# Epoch 78/5000
# 34/34 - 0s - loss: 2.7607e-04 - val_loss: 3.2311e-04
# Epoch 79/5000
# 34/34 - 0s - loss: 2.9985e-04 - val_loss: 2.3421e-04
# Epoch 80/5000
# 34/34 - 0s - loss: 2.8392e-04 - val_loss: 3.0426e-04
# Epoch 81/5000
# 34/34 - 0s - loss: 2.6708e-04 - val_loss: 2.3212e-04
# Epoch 82/5000
# 34/34 - 0s - loss: 2.6262e-04 - val_loss: 2.4211e-04
# Epoch 83/5000
# 34/34 - 0s - loss: 2.7363e-04 - val_loss: 2.3535e-04
# Epoch 84/5000
# 34/34 - 0s - loss: 2.7220e-04 - val_loss: 2.4340e-04
# Epoch 85/5000
# 34/34 - 0s - loss: 2.6888e-04 - val_loss: 2.3182e-04
# Epoch 86/5000
# 34/34 - 0s - loss: 2.6817e-04 - val_loss: 2.3344e-04
# Epoch 87/5000
# 34/34 - 0s - loss: 2.7218e-04 - val_loss: 2.7183e-04
# Epoch 88/5000
# 34/34 - 0s - loss: 2.6615e-04 - val_loss: 2.3877e-04
# Epoch 89/5000
# 34/34 - 0s - loss: 2.6852e-04 - val_loss: 2.9457e-04
# Epoch 90/5000
# 34/34 - 0s - loss: 2.6530e-04 - val_loss: 2.3317e-04
# Epoch 91/5000
# 34/34 - 0s - loss: 2.6507e-04 - val_loss: 2.4123e-04
# Epoch 92/5000
# 34/34 - 0s - loss: 2.7544e-04 - val_loss: 2.2929e-04
# Epoch 93/5000
# 34/34 - 0s - loss: 2.6436e-04 - val_loss: 2.4266e-04
# Epoch 94/5000
# 34/34 - 0s - loss: 2.6325e-04 - val_loss: 3.1231e-04
# Epoch 95/5000
# 34/34 - 0s - loss: 2.6982e-04 - val_loss: 2.2709e-04
# Epoch 96/5000
# 34/34 - 0s - loss: 2.6242e-04 - val_loss: 2.6868e-04
# Epoch 97/5000
# 34/34 - 0s - loss: 2.6854e-04 - val_loss: 2.3729e-04
# Epoch 98/5000
# 34/34 - 0s - loss: 2.7507e-04 - val_loss: 2.2672e-04
# Epoch 99/5000
# 34/34 - 0s - loss: 2.7179e-04 - val_loss: 2.6072e-04
# Epoch 100/5000
# 34/34 - 0s - loss: 2.5671e-04 - val_loss: 2.5451e-04
# Epoch 101/5000
# 34/34 - 0s - loss: 2.6888e-04 - val_loss: 2.2614e-04
# Epoch 102/5000
# 34/34 - 0s - loss: 2.6155e-04 - val_loss: 2.2311e-04
# Epoch 103/5000
# 34/34 - 0s - loss: 2.5331e-04 - val_loss: 2.5026e-04
# Epoch 104/5000
# 34/34 - 0s - loss: 2.5788e-04 - val_loss: 2.3329e-04
# Epoch 105/5000
# 34/34 - 0s - loss: 2.6232e-04 - val_loss: 2.2178e-04
# Epoch 106/5000
# 34/34 - 0s - loss: 3.0484e-04 - val_loss: 2.5372e-04
# Epoch 107/5000
# 34/34 - 0s - loss: 2.5710e-04 - val_loss: 2.2328e-04
# Epoch 108/5000
# 34/34 - 0s - loss: 2.5859e-04 - val_loss: 2.3075e-04
# Epoch 109/5000
# 34/34 - 0s - loss: 2.5670e-04 - val_loss: 2.2256e-04
# Epoch 110/5000
# 34/34 - 0s - loss: 2.5629e-04 - val_loss: 2.1885e-04
# Epoch 111/5000
# 34/34 - 0s - loss: 2.6762e-04 - val_loss: 2.4266e-04
# Epoch 112/5000
# 34/34 - 0s - loss: 2.5830e-04 - val_loss: 2.2864e-04
# Epoch 113/5000
# 34/34 - 0s - loss: 2.5371e-04 - val_loss: 2.2736e-04
# Epoch 114/5000
# 34/34 - 0s - loss: 2.6878e-04 - val_loss: 2.4136e-04
# Epoch 115/5000
# 34/34 - 0s - loss: 2.5859e-04 - val_loss: 2.5367e-04
# Epoch 116/5000
# 34/34 - 0s - loss: 2.5912e-04 - val_loss: 2.5443e-04
# Epoch 117/5000
# 34/34 - 0s - loss: 2.6547e-04 - val_loss: 2.4881e-04
# Epoch 118/5000
# 34/34 - 0s - loss: 2.6845e-04 - val_loss: 2.3649e-04
# Epoch 119/5000
# 34/34 - 0s - loss: 2.5520e-04 - val_loss: 2.4309e-04
# Epoch 120/5000
# 34/34 - 0s - loss: 2.7151e-04 - val_loss: 2.1878e-04
# Epoch 121/5000
# 34/34 - 0s - loss: 2.5615e-04 - val_loss: 2.3101e-04
# Epoch 122/5000
# 34/34 - 0s - loss: 2.5483e-04 - val_loss: 2.3016e-04
# Epoch 123/5000
# 34/34 - 0s - loss: 2.6472e-04 - val_loss: 2.2610e-04
# Epoch 124/5000
# 34/34 - 0s - loss: 2.5542e-04 - val_loss: 2.2166e-04
# Epoch 125/5000
# 34/34 - 0s - loss: 2.4854e-04 - val_loss: 2.2292e-04
# Epoch 126/5000
# 34/34 - 0s - loss: 2.5338e-04 - val_loss: 2.5884e-04
# Epoch 127/5000
# 34/34 - 0s - loss: 2.5558e-04 - val_loss: 2.2091e-04
# Epoch 128/5000
# 34/34 - 0s - loss: 2.5249e-04 - val_loss: 2.3628e-04
# Epoch 129/5000
# 34/34 - 0s - loss: 2.8344e-04 - val_loss: 2.6122e-04
# Epoch 130/5000
# 34/34 - 0s - loss: 2.9016e-04 - val_loss: 2.5951e-04
# Epoch 131/5000
# 34/34 - 0s - loss: 2.5743e-04 - val_loss: 2.3278e-04
# Epoch 132/5000
# 34/34 - 0s - loss: 2.5136e-04 - val_loss: 2.2346e-04
# Epoch 133/5000
# 34/34 - 0s - loss: 2.5078e-04 - val_loss: 2.7977e-04
# Epoch 134/5000
# 34/34 - 0s - loss: 2.6411e-04 - val_loss: 2.2648e-04
# Epoch 135/5000
# 34/34 - 0s - loss: 2.5829e-04 - val_loss: 2.3086e-04
# Epoch 136/5000
# 34/34 - 0s - loss: 2.6012e-04 - val_loss: 2.2333e-04
# Epoch 137/5000
# 34/34 - 0s - loss: 2.5563e-04 - val_loss: 2.1545e-04
# Epoch 138/5000
# 34/34 - 0s - loss: 2.4653e-04 - val_loss: 2.2657e-04
# Epoch 139/5000
# 34/34 - 0s - loss: 2.5644e-04 - val_loss: 2.2396e-04
# Epoch 140/5000
# 34/34 - 0s - loss: 2.5847e-04 - val_loss: 2.2386e-04
# Epoch 141/5000
# 34/34 - 0s - loss: 2.5213e-04 - val_loss: 2.1598e-04
# Epoch 142/5000
# 34/34 - 0s - loss: 2.4527e-04 - val_loss: 2.2332e-04
# Epoch 143/5000
# 34/34 - 0s - loss: 2.5506e-04 - val_loss: 2.4940e-04
# Epoch 144/5000
# 34/34 - 0s - loss: 2.4035e-04 - val_loss: 2.1052e-04
# Epoch 145/5000
# 34/34 - 0s - loss: 2.4565e-04 - val_loss: 2.1858e-04
# Epoch 146/5000
# 34/34 - 0s - loss: 2.4568e-04 - val_loss: 2.1443e-04
# Epoch 147/5000
# 34/34 - 0s - loss: 2.4962e-04 - val_loss: 2.5714e-04
# Epoch 148/5000
# 34/34 - 0s - loss: 2.4597e-04 - val_loss: 2.6163e-04
# Epoch 149/5000
# 34/34 - 0s - loss: 2.6571e-04 - val_loss: 2.1737e-04
# Epoch 150/5000
# 34/34 - 0s - loss: 2.4479e-04 - val_loss: 2.3181e-04
# Epoch 151/5000
# 34/34 - 0s - loss: 2.5518e-04 - val_loss: 2.2296e-04
# Epoch 152/5000
# 34/34 - 0s - loss: 2.5585e-04 - val_loss: 2.1501e-04
# Epoch 153/5000
# 34/34 - 0s - loss: 2.4597e-04 - val_loss: 2.2034e-04
# Epoch 154/5000
# 34/34 - 0s - loss: 2.4269e-04 - val_loss: 2.2182e-04
# Epoch 155/5000
# 34/34 - 0s - loss: 2.4649e-04 - val_loss: 2.1951e-04
# Epoch 156/5000
# 34/34 - 0s - loss: 2.4480e-04 - val_loss: 2.1111e-04
# Epoch 157/5000
# 34/34 - 0s - loss: 2.5680e-04 - val_loss: 2.5574e-04
# Epoch 158/5000
# 34/34 - 0s - loss: 2.5430e-04 - val_loss: 2.3678e-04
# Epoch 159/5000
# 34/34 - 0s - loss: 2.4673e-04 - val_loss: 2.2665e-04
# Epoch 160/5000
# 34/34 - 0s - loss: 2.5878e-04 - val_loss: 2.4718e-04
# Epoch 161/5000
# 34/34 - 0s - loss: 2.5282e-04 - val_loss: 2.3002e-04
# Epoch 162/5000
# 34/34 - 0s - loss: 2.5300e-04 - val_loss: 2.3365e-04
# Epoch 163/5000
# 34/34 - 0s - loss: 2.5918e-04 - val_loss: 2.2433e-04
# Epoch 164/5000
# 34/34 - 0s - loss: 2.4866e-04 - val_loss: 2.5127e-04
# Epoch 165/5000
# 34/34 - 0s - loss: 2.4833e-04 - val_loss: 2.1485e-04
# Epoch 166/5000
# 34/34 - 0s - loss: 2.5117e-04 - val_loss: 2.1624e-04
# Epoch 167/5000
# 34/34 - 0s - loss: 2.6451e-04 - val_loss: 2.2906e-04
# Epoch 168/5000
# 34/34 - 0s - loss: 2.5216e-04 - val_loss: 2.6889e-04
# Epoch 169/5000
# 34/34 - 0s - loss: 2.5599e-04 - val_loss: 2.1325e-04
# Epoch 170/5000
# 34/34 - 0s - loss: 2.4289e-04 - val_loss: 2.0944e-04
# Epoch 171/5000
# 34/34 - 0s - loss: 2.4123e-04 - val_loss: 2.1243e-04
# Epoch 172/5000
# 34/34 - 0s - loss: 2.5254e-04 - val_loss: 2.1046e-04
# Epoch 173/5000
# 34/34 - 0s - loss: 2.5401e-04 - val_loss: 2.1623e-04
# Epoch 174/5000
# 34/34 - 0s - loss: 2.4674e-04 - val_loss: 2.2159e-04
# Epoch 175/5000
# 34/34 - 0s - loss: 2.4980e-04 - val_loss: 2.2528e-04
# Epoch 176/5000
# 34/34 - 0s - loss: 2.6150e-04 - val_loss: 2.2953e-04
# Epoch 177/5000
# 34/34 - 0s - loss: 2.5228e-04 - val_loss: 2.5645e-04
# Epoch 178/5000
# 34/34 - 0s - loss: 2.6204e-04 - val_loss: 2.5742e-04
# Epoch 179/5000
# 34/34 - 0s - loss: 2.4935e-04 - val_loss: 2.1578e-04
# Epoch 180/5000
# 34/34 - 0s - loss: 2.5619e-04 - val_loss: 2.2696e-04
# Epoch 181/5000
# 34/34 - 0s - loss: 2.5281e-04 - val_loss: 2.2552e-04
# Epoch 182/5000
# 34/34 - 0s - loss: 2.4495e-04 - val_loss: 2.2168e-04
# Epoch 183/5000
# 34/34 - 0s - loss: 2.4788e-04 - val_loss: 2.2248e-04
# Epoch 184/5000
# 34/34 - 0s - loss: 2.4019e-04 - val_loss: 2.0740e-04
# Epoch 185/5000
# 34/34 - 0s - loss: 2.4679e-04 - val_loss: 2.2333e-04
# Epoch 186/5000
# 34/34 - 0s - loss: 2.4973e-04 - val_loss: 2.1395e-04
# Epoch 187/5000
# 34/34 - 0s - loss: 2.4322e-04 - val_loss: 2.1042e-04
# Epoch 188/5000
# 34/34 - 0s - loss: 2.4911e-04 - val_loss: 2.1331e-04
# Epoch 189/5000
# 34/34 - 0s - loss: 2.4825e-04 - val_loss: 2.5932e-04
# Epoch 190/5000
# 34/34 - 0s - loss: 2.7304e-04 - val_loss: 2.2015e-04
# Epoch 191/5000
# 34/34 - 0s - loss: 2.6086e-04 - val_loss: 2.2072e-04
# Epoch 192/5000
# 34/34 - 0s - loss: 2.5000e-04 - val_loss: 2.2877e-04
# Epoch 193/5000
# 34/34 - 0s - loss: 2.5698e-04 - val_loss: 2.0944e-04
# Epoch 194/5000
# 34/34 - 0s - loss: 2.3792e-04 - val_loss: 2.0940e-04
# Epoch 195/5000
# 34/34 - 0s - loss: 2.5087e-04 - val_loss: 2.2917e-04
# Epoch 196/5000
# 34/34 - 0s - loss: 2.4231e-04 - val_loss: 2.1128e-04
# Epoch 197/5000
# 34/34 - 0s - loss: 2.4071e-04 - val_loss: 2.2736e-04
# Epoch 198/5000
# 34/34 - 0s - loss: 2.4035e-04 - val_loss: 2.6515e-04
# Epoch 199/5000
# 34/34 - 0s - loss: 2.4818e-04 - val_loss: 2.2103e-04
# Epoch 200/5000
# 34/34 - 0s - loss: 2.4288e-04 - val_loss: 2.1445e-04
# Epoch 201/5000
# 34/34 - 0s - loss: 2.4480e-04 - val_loss: 2.1971e-04
# Epoch 202/5000
# 34/34 - 0s - loss: 2.5141e-04 - val_loss: 2.3723e-04
# Epoch 203/5000
# 34/34 - 0s - loss: 2.4592e-04 - val_loss: 2.2057e-04
# Epoch 204/5000
# 34/34 - 0s - loss: 2.3897e-04 - val_loss: 2.1519e-04
# Epoch 205/5000
# 34/34 - 0s - loss: 2.4418e-04 - val_loss: 2.0886e-04
# Epoch 206/5000
# 34/34 - 0s - loss: 2.4114e-04 - val_loss: 2.0760e-04
# Epoch 207/5000
# 34/34 - 0s - loss: 2.4665e-04 - val_loss: 2.3958e-04
# Epoch 208/5000
# 34/34 - 0s - loss: 2.6610e-04 - val_loss: 2.4216e-04
# Epoch 209/5000
# 34/34 - 0s - loss: 2.4170e-04 - val_loss: 2.3019e-04
# Epoch 210/5000
# 34/34 - 0s - loss: 2.6399e-04 - val_loss: 2.3467e-04
# Epoch 211/5000
# 34/34 - 0s - loss: 2.3939e-04 - val_loss: 2.1182e-04
# Epoch 212/5000
# 34/34 - 0s - loss: 2.4274e-04 - val_loss: 2.3301e-04
# Epoch 213/5000
# 34/34 - 0s - loss: 2.5720e-04 - val_loss: 2.3411e-04
# Epoch 214/5000
# 34/34 - 0s - loss: 2.3721e-04 - val_loss: 2.0825e-04
# Epoch 215/5000
# 34/34 - 0s - loss: 2.4428e-04 - val_loss: 2.3846e-04
# Epoch 216/5000
# 34/34 - 0s - loss: 2.4544e-04 - val_loss: 2.1738e-04
# Epoch 217/5000
# 34/34 - 0s - loss: 2.5533e-04 - val_loss: 2.1670e-04
# Epoch 218/5000
# 34/34 - 0s - loss: 2.3561e-04 - val_loss: 2.0128e-04
# Epoch 219/5000
# 34/34 - 0s - loss: 2.3547e-04 - val_loss: 2.0497e-04
# Epoch 220/5000
# 34/34 - 0s - loss: 2.3623e-04 - val_loss: 2.1488e-04
# Epoch 221/5000
# 34/34 - 0s - loss: 2.3891e-04 - val_loss: 2.2200e-04
# Epoch 222/5000
# 34/34 - 0s - loss: 2.5403e-04 - val_loss: 2.6667e-04
# Epoch 223/5000
# 34/34 - 0s - loss: 2.4931e-04 - val_loss: 2.1814e-04
# Epoch 224/5000
# 34/34 - 0s - loss: 2.3575e-04 - val_loss: 2.0327e-04
# Epoch 225/5000
# 34/34 - 0s - loss: 2.3760e-04 - val_loss: 2.2878e-04
# Epoch 226/5000
# 34/34 - 0s - loss: 2.5310e-04 - val_loss: 2.1503e-04
# Epoch 227/5000
# 34/34 - 0s - loss: 2.4245e-04 - val_loss: 2.6424e-04
# Epoch 228/5000
# 34/34 - 0s - loss: 2.3988e-04 - val_loss: 2.0356e-04
# Epoch 229/5000
# 34/34 - 0s - loss: 2.4239e-04 - val_loss: 2.4276e-04
# Epoch 230/5000
# 34/34 - 0s - loss: 2.4379e-04 - val_loss: 2.1029e-04
# Epoch 231/5000
# 34/34 - 0s - loss: 2.4212e-04 - val_loss: 2.2505e-04
# Epoch 232/5000
# 34/34 - 0s - loss: 2.4373e-04 - val_loss: 2.1247e-04
# Epoch 233/5000
# 34/34 - 0s - loss: 2.3203e-04 - val_loss: 2.1661e-04
# Epoch 234/5000
# 34/34 - 0s - loss: 2.4011e-04 - val_loss: 2.7097e-04
# Epoch 235/5000
# 34/34 - 0s - loss: 2.5950e-04 - val_loss: 2.2238e-04
# Epoch 236/5000
# 34/34 - 0s - loss: 2.4801e-04 - val_loss: 2.3129e-04
# Epoch 237/5000
# 34/34 - 0s - loss: 2.5463e-04 - val_loss: 2.1350e-04
# Epoch 238/5000
# 34/34 - 0s - loss: 2.4406e-04 - val_loss: 2.9169e-04
# Epoch 239/5000
# 34/34 - 0s - loss: 2.4518e-04 - val_loss: 2.5754e-04
# Epoch 240/5000
# 34/34 - 0s - loss: 2.5015e-04 - val_loss: 2.2657e-04
# Epoch 241/5000
# 34/34 - 0s - loss: 2.4957e-04 - val_loss: 2.3833e-04
# Epoch 242/5000
# 34/34 - 0s - loss: 2.5337e-04 - val_loss: 2.2775e-04
# Epoch 243/5000
# 34/34 - 0s - loss: 2.3603e-04 - val_loss: 2.1138e-04
# Epoch 244/5000
# 34/34 - 0s - loss: 2.4428e-04 - val_loss: 2.1489e-04
# Epoch 245/5000
# 34/34 - 0s - loss: 2.3568e-04 - val_loss: 2.1117e-04
# Epoch 246/5000
# 34/34 - 0s - loss: 2.3850e-04 - val_loss: 2.7211e-04
# Epoch 247/5000
# 34/34 - 0s - loss: 2.5665e-04 - val_loss: 2.2447e-04
# Epoch 248/5000
# 34/34 - 0s - loss: 2.5294e-04 - val_loss: 2.1581e-04
# Epoch 249/5000
# 34/34 - 0s - loss: 2.4120e-04 - val_loss: 2.1601e-04
# Epoch 250/5000
# 34/34 - 0s - loss: 2.3453e-04 - val_loss: 2.1771e-04
# Epoch 251/5000
# 34/34 - 0s - loss: 2.3949e-04 - val_loss: 2.2697e-04
# Epoch 252/5000
# 34/34 - 0s - loss: 2.4371e-04 - val_loss: 2.1511e-04
# Epoch 253/5000
# 34/34 - 0s - loss: 2.3680e-04 - val_loss: 2.0172e-04
# Epoch 254/5000
# 34/34 - 0s - loss: 2.2916e-04 - val_loss: 2.1201e-04
# Epoch 255/5000
# 34/34 - 0s - loss: 2.3108e-04 - val_loss: 2.1096e-04
# Epoch 256/5000
# 34/34 - 0s - loss: 2.3484e-04 - val_loss: 2.2559e-04
# Epoch 257/5000
# 34/34 - 0s - loss: 2.4278e-04 - val_loss: 2.2270e-04
# Epoch 258/5000
# 34/34 - 0s - loss: 2.3779e-04 - val_loss: 2.0459e-04
# Epoch 259/5000
# 34/34 - 0s - loss: 2.3815e-04 - val_loss: 2.1133e-04
# Epoch 260/5000
# 34/34 - 0s - loss: 2.5009e-04 - val_loss: 2.2320e-04
# Epoch 261/5000
# 34/34 - 0s - loss: 2.3611e-04 - val_loss: 2.0954e-04
# Epoch 262/5000
# 34/34 - 0s - loss: 2.3799e-04 - val_loss: 2.1186e-04
# Epoch 263/5000
# 34/34 - 0s - loss: 2.4664e-04 - val_loss: 2.3396e-04
# Epoch 264/5000
# 34/34 - 0s - loss: 2.3392e-04 - val_loss: 2.2325e-04
# Epoch 265/5000
# 34/34 - 0s - loss: 2.5094e-04 - val_loss: 2.5718e-04
# Epoch 266/5000
# 34/34 - 0s - loss: 2.4486e-04 - val_loss: 2.0888e-04
# Epoch 267/5000
# 34/34 - 0s - loss: 2.4654e-04 - val_loss: 2.5116e-04
# Epoch 268/5000
# 34/34 - 0s - loss: 2.4100e-04 - val_loss: 2.1132e-04
# Epoch 269/5000
# 34/34 - 0s - loss: 2.4939e-04 - val_loss: 2.7300e-04
# Epoch 270/5000
# 34/34 - 0s - loss: 2.4193e-04 - val_loss: 2.1063e-04
# Epoch 271/5000
# 34/34 - 0s - loss: 2.3626e-04 - val_loss: 2.0887e-04
# Epoch 272/5000
# 34/34 - 0s - loss: 2.3653e-04 - val_loss: 2.1826e-04
# Epoch 273/5000
# 34/34 - 0s - loss: 2.3902e-04 - val_loss: 2.2815e-04
# Epoch 274/5000
# 34/34 - 0s - loss: 2.4038e-04 - val_loss: 2.1319e-04
# Epoch 275/5000
# 34/34 - 0s - loss: 2.4066e-04 - val_loss: 2.1136e-04
# Epoch 276/5000
# 34/34 - 0s - loss: 2.3255e-04 - val_loss: 2.2354e-04
# Epoch 277/5000
# 34/34 - 0s - loss: 2.3656e-04 - val_loss: 2.2478e-04
# Epoch 278/5000
# 34/34 - 0s - loss: 2.3645e-04 - val_loss: 2.1567e-04
# Epoch 279/5000
# 34/34 - 0s - loss: 2.3638e-04 - val_loss: 2.0370e-04
# Epoch 280/5000
# 34/34 - 0s - loss: 2.4397e-04 - val_loss: 2.2870e-04
# Epoch 281/5000
# 34/34 - 0s - loss: 2.4747e-04 - val_loss: 2.1105e-04
# Epoch 282/5000
# 34/34 - 0s - loss: 2.3144e-04 - val_loss: 2.0281e-04
# Epoch 283/5000
# 34/34 - 0s - loss: 2.5188e-04 - val_loss: 2.6485e-04
# Epoch 284/5000
# 34/34 - 0s - loss: 2.3846e-04 - val_loss: 2.5323e-04
# Epoch 285/5000
# 34/34 - 0s - loss: 2.3935e-04 - val_loss: 2.0864e-04
# Epoch 286/5000
# 34/34 - 0s - loss: 2.2599e-04 - val_loss: 2.0079e-04
# Epoch 287/5000
# 34/34 - 0s - loss: 2.3014e-04 - val_loss: 1.9938e-04
# Epoch 288/5000
# 34/34 - 0s - loss: 2.2933e-04 - val_loss: 1.9755e-04
# Epoch 289/5000
# 34/34 - 0s - loss: 2.3644e-04 - val_loss: 2.2909e-04
# Epoch 290/5000
# 34/34 - 0s - loss: 2.3220e-04 - val_loss: 1.9933e-04
# Epoch 291/5000
# 34/34 - 0s - loss: 2.3098e-04 - val_loss: 2.1382e-04
# Epoch 292/5000
# 34/34 - 0s - loss: 2.3681e-04 - val_loss: 2.0535e-04
# Epoch 293/5000
# 34/34 - 0s - loss: 2.4324e-04 - val_loss: 2.2206e-04
# Epoch 294/5000
# 34/34 - 0s - loss: 2.3457e-04 - val_loss: 2.0936e-04
# Epoch 295/5000
# 34/34 - 0s - loss: 2.4447e-04 - val_loss: 2.2221e-04
# Epoch 296/5000
# 34/34 - 0s - loss: 2.4440e-04 - val_loss: 2.6839e-04
# Epoch 297/5000
# 34/34 - 0s - loss: 2.3824e-04 - val_loss: 2.0988e-04
# Epoch 298/5000
# 34/34 - 0s - loss: 2.3049e-04 - val_loss: 2.1528e-04
# Epoch 299/5000
# 34/34 - 0s - loss: 2.3914e-04 - val_loss: 2.3202e-04
# Epoch 300/5000
# 34/34 - 0s - loss: 2.3995e-04 - val_loss: 2.2151e-04
# Epoch 301/5000
# 34/34 - 0s - loss: 2.3301e-04 - val_loss: 2.0663e-04
# Epoch 302/5000
# 34/34 - 0s - loss: 2.3846e-04 - val_loss: 1.9983e-04
# Epoch 303/5000
# 34/34 - 0s - loss: 2.3634e-04 - val_loss: 2.0701e-04
# Epoch 304/5000
# 34/34 - 0s - loss: 2.3834e-04 - val_loss: 3.0401e-04
# Epoch 305/5000
# 34/34 - 0s - loss: 2.4575e-04 - val_loss: 2.2364e-04
# Epoch 306/5000
# 34/34 - 0s - loss: 2.3743e-04 - val_loss: 2.0190e-04
# Epoch 307/5000
# 34/34 - 0s - loss: 2.3009e-04 - val_loss: 2.0064e-04
# Epoch 308/5000
# 34/34 - 0s - loss: 2.2960e-04 - val_loss: 2.1168e-04
# Epoch 309/5000
# 34/34 - 0s - loss: 2.2293e-04 - val_loss: 2.0271e-04
# Epoch 310/5000
# 34/34 - 0s - loss: 2.2574e-04 - val_loss: 2.6081e-04
# Epoch 311/5000
# 34/34 - 0s - loss: 2.5904e-04 - val_loss: 2.4381e-04
# Epoch 312/5000
# 34/34 - 0s - loss: 2.5054e-04 - val_loss: 2.3598e-04
# Epoch 313/5000
# 34/34 - 0s - loss: 2.3371e-04 - val_loss: 2.0026e-04
# Epoch 314/5000
# 34/34 - 0s - loss: 2.3514e-04 - val_loss: 2.0179e-04
# Epoch 315/5000
# 34/34 - 0s - loss: 2.4043e-04 - val_loss: 2.0440e-04
# Epoch 316/5000
# 34/34 - 0s - loss: 2.3073e-04 - val_loss: 2.0348e-04
# Epoch 317/5000
# 34/34 - 0s - loss: 2.3027e-04 - val_loss: 2.0706e-04
# Epoch 318/5000
# 34/34 - 0s - loss: 2.2802e-04 - val_loss: 2.1503e-04
# Epoch 319/5000
# 34/34 - 0s - loss: 2.2534e-04 - val_loss: 1.9996e-04
# Epoch 320/5000
# 34/34 - 0s - loss: 2.4152e-04 - val_loss: 2.0722e-04
# Epoch 321/5000
# 34/34 - 0s - loss: 2.3661e-04 - val_loss: 1.9981e-04
# Epoch 322/5000
# 34/34 - 0s - loss: 2.3795e-04 - val_loss: 2.0231e-04
# Epoch 323/5000
# 34/34 - 0s - loss: 2.3997e-04 - val_loss: 2.0460e-04
# Epoch 324/5000
# 34/34 - 0s - loss: 2.3499e-04 - val_loss: 1.9953e-04
# Epoch 325/5000
# 34/34 - 0s - loss: 2.3752e-04 - val_loss: 2.2534e-04
# Epoch 326/5000
# 34/34 - 0s - loss: 2.3932e-04 - val_loss: 2.0053e-04
# Epoch 327/5000
# 34/34 - 0s - loss: 2.4530e-04 - val_loss: 1.9986e-04
# Epoch 328/5000
# 34/34 - 0s - loss: 2.2577e-04 - val_loss: 2.0331e-04
# Epoch 329/5000
# 34/34 - 0s - loss: 2.2741e-04 - val_loss: 2.2173e-04
# Epoch 330/5000
# 34/34 - 0s - loss: 2.4032e-04 - val_loss: 2.0505e-04
# Epoch 331/5000
# 34/34 - 0s - loss: 2.2571e-04 - val_loss: 2.2856e-04
# Epoch 332/5000
# 34/34 - 0s - loss: 2.3604e-04 - val_loss: 1.9924e-04
# Epoch 333/5000
# 34/34 - 0s - loss: 2.3379e-04 - val_loss: 2.0760e-04
# Epoch 334/5000
# 34/34 - 0s - loss: 2.2783e-04 - val_loss: 1.9896e-04
# Epoch 335/5000
# 34/34 - 0s - loss: 2.3264e-04 - val_loss: 2.3716e-04
# Epoch 336/5000
# 34/34 - 0s - loss: 2.3532e-04 - val_loss: 2.1039e-04
# Epoch 337/5000
# 34/34 - 0s - loss: 2.3420e-04 - val_loss: 1.9864e-04
# Epoch 338/5000
# 34/34 - 0s - loss: 2.3639e-04 - val_loss: 2.0912e-04
# Epoch 339/5000
# 34/34 - 0s - loss: 2.2592e-04 - val_loss: 2.0176e-04
# Epoch 340/5000
# 34/34 - 0s - loss: 2.2496e-04 - val_loss: 2.0191e-04
# Epoch 341/5000
# 34/34 - 0s - loss: 2.2877e-04 - val_loss: 1.9740e-04
# Epoch 342/5000
# 34/34 - 0s - loss: 2.1903e-04 - val_loss: 2.0120e-04
# Epoch 343/5000
# 34/34 - 0s - loss: 2.2490e-04 - val_loss: 1.9990e-04
# Epoch 344/5000
# 34/34 - 0s - loss: 2.2475e-04 - val_loss: 1.9708e-04
# Epoch 345/5000
# 34/34 - 0s - loss: 2.3678e-04 - val_loss: 2.0368e-04
# Epoch 346/5000
# 34/34 - 0s - loss: 2.3756e-04 - val_loss: 2.9235e-04
# Epoch 347/5000
# 34/34 - 0s - loss: 2.4674e-04 - val_loss: 1.9858e-04
# Epoch 348/5000
# 34/34 - 0s - loss: 2.5138e-04 - val_loss: 2.1312e-04
# Epoch 349/5000
# 34/34 - 0s - loss: 2.4031e-04 - val_loss: 2.1019e-04
# Epoch 350/5000
# 34/34 - 0s - loss: 2.4591e-04 - val_loss: 2.2023e-04
# Epoch 351/5000
# 34/34 - 0s - loss: 2.3325e-04 - val_loss: 2.2007e-04
# Epoch 352/5000
# 34/34 - 0s - loss: 2.5022e-04 - val_loss: 2.0382e-04
# Epoch 353/5000
# 34/34 - 0s - loss: 2.4368e-04 - val_loss: 2.1103e-04
# Epoch 354/5000
# 34/34 - 0s - loss: 2.3669e-04 - val_loss: 2.1515e-04
# Epoch 355/5000
# 34/34 - 0s - loss: 2.3207e-04 - val_loss: 1.9902e-04
# Epoch 356/5000
# 34/34 - 0s - loss: 2.4093e-04 - val_loss: 2.1848e-04
# Epoch 357/5000
# 34/34 - 0s - loss: 2.3284e-04 - val_loss: 2.0831e-04
# Epoch 358/5000
# 34/34 - 0s - loss: 2.2846e-04 - val_loss: 2.1695e-04
# Epoch 359/5000
# 34/34 - 0s - loss: 2.3241e-04 - val_loss: 1.9517e-04
# Epoch 360/5000
# 34/34 - 0s - loss: 2.2173e-04 - val_loss: 2.1143e-04
# Epoch 361/5000
# 34/34 - 0s - loss: 2.3574e-04 - val_loss: 2.0081e-04
# Epoch 362/5000
# 34/34 - 0s - loss: 2.2523e-04 - val_loss: 2.2729e-04
# Epoch 363/5000
# 34/34 - 0s - loss: 2.3071e-04 - val_loss: 2.0173e-04
# Epoch 364/5000
# 34/34 - 0s - loss: 2.2320e-04 - val_loss: 2.1080e-04
# Epoch 365/5000
# 34/34 - 0s - loss: 2.2934e-04 - val_loss: 2.1597e-04
# Epoch 366/5000
# 34/34 - 0s - loss: 2.3399e-04 - val_loss: 1.9876e-04
# Epoch 367/5000
# 34/34 - 0s - loss: 2.3093e-04 - val_loss: 2.1699e-04
# Epoch 368/5000
# 34/34 - 0s - loss: 2.2491e-04 - val_loss: 2.0497e-04
# Epoch 369/5000
# 34/34 - 0s - loss: 2.4550e-04 - val_loss: 2.1426e-04
# Epoch 370/5000
# 34/34 - 0s - loss: 2.3233e-04 - val_loss: 1.9881e-04
# Epoch 371/5000
# 34/34 - 0s - loss: 2.4166e-04 - val_loss: 2.0282e-04
# Epoch 372/5000
# 34/34 - 0s - loss: 2.2889e-04 - val_loss: 1.9740e-04
# Epoch 373/5000
# 34/34 - 0s - loss: 2.3705e-04 - val_loss: 2.2540e-04
# Epoch 374/5000
# 34/34 - 0s - loss: 2.5273e-04 - val_loss: 2.2108e-04
# Epoch 375/5000
# 34/34 - 0s - loss: 2.3670e-04 - val_loss: 2.1706e-04
# Epoch 376/5000
# 34/34 - 0s - loss: 2.3247e-04 - val_loss: 1.9835e-04
# Epoch 377/5000
# 34/34 - 0s - loss: 2.2752e-04 - val_loss: 2.3199e-04
# Epoch 378/5000
# 34/34 - 0s - loss: 2.5016e-04 - val_loss: 2.7033e-04
# Epoch 379/5000
# 34/34 - 0s - loss: 2.3629e-04 - val_loss: 1.9139e-04
# Epoch 380/5000
# 34/34 - 0s - loss: 2.2554e-04 - val_loss: 2.1006e-04
# Epoch 381/5000
# 34/34 - 0s - loss: 2.2411e-04 - val_loss: 1.9789e-04
# Epoch 382/5000
# 34/34 - 0s - loss: 2.2124e-04 - val_loss: 2.0293e-04

# %% [markdown]
# ### 5. Check training results
#
# Examine how well the network was trained by evaluating the model (i.e. computing the loss function) on the validation data and looking into the training history. Keep an eye on the order of magnitude of the loss function and any evidence of overfitting or underfitting.

# %%
loss = model.evaluate(x_vl, y_vl, verbose=0)
print("Loss = {:.4e}".format(loss))
# Out:
# Loss = 1.7869e-04

# %%
plt.figure(figsize=(10,7))
plt.semilogy(training.history['loss'], ls='--', color='red', label='train')
plt.semilogy(training.history['val_loss'], color='orange', label='test')
plt.grid()
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.title("Training History")
plt.legend()
plt.show()

# %% [markdown]
# ### 6. Predict EoS and compare with data
#
# Evaluate model with validation data and de-normalize data and prediction.

# %%
x = x_vl
y = y_vl
pd = np.array(model(x))

# De-normalize data and prediction
pr = np.min(P) + (np.max(P) - np.min(P)) * pd
dt = np.min(P) + (np.max(P) - np.min(P)) * y

# %% [markdown]
# Choose a random $M-R$ curve and predict the corresponding EoS. Plot the predicted EoS and the data for comparison.

# %%
i = np.random.choice(x_vl.shape[0])

plt.figure(figsize=(10,7))
plt.plot(pr[i], color='blue', label='prediction')
plt.plot(dt[i], color='red', label='3P data')

plt.title("3P EoS: Data Vs. Prediction")
plt.ylabel("Pressure ($Mev/fm^3$)")
plt.legend()
plt.grid()
#plt.savefig(f"{FIGS}/real_vs_models.png")
plt.show()
