# %% [markdown]
# ## Process Tidal Data

# %%
import os
import pandas as pd
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# ### 1. Read and load data from file
#
# First, read the data file containing the neutron star (NS) equations of states (EoS) and their mass-radius ($M-R$) curves. Look at the first few rows of all columns.

# %%
df = pd.read_csv("tidal.csv", low_memory=False)
df.head()
# Out:
#        ed_0      P_0       M_0       R_0      ed_1      P_1       M_1  \
# 0  0.000236  0.00001  0.500000  12.51064  0.000237  0.00001  0.507602
# 1  0.000236  0.00001  0.500004  12.51063  0.000237  0.00001  0.505010
# 2  0.000236  0.00001  0.500004  12.51063  0.000237  0.00001  0.507147
# 3  0.000236  0.00001  0.500004  12.51063  0.000237  0.00001  0.506535
# 4  0.000236  0.00001  0.500004  12.51063  0.000237  0.00001  0.505848
#
#         R_1      ed_2       P_2  ...     M_197      R_197    ed_198     P_198  \
# 0  12.48922  0.000239  0.000011  ...  1.817522   8.973816  0.001920  0.001157
# 1  12.49639  0.000238  0.000010  ...  1.915204  11.309820  0.000779  0.000231
# 2  12.49047  0.000239  0.000011  ...  1.815871   9.185647  0.001760  0.000871
# 3  12.49215  0.000239  0.000011  ...  1.610028   9.399669  0.001757  0.000596
# 4  12.49407  0.000238  0.000010  ...  1.891711  10.642860  0.001410  0.000389
#
#       M_198      R_198    ed_199     P_199     M_199      R_199
# ...

# %% [markdown]
# The columns $\mathrm{ed}_0 \cdots \mathrm{ed}_{199}$ are energy densities, $P_0 \cdots P_{199}$ are pressures, $M_0 \cdots M_{199}$ are masses, and $R_0 \cdots R_{199}$ are radii of neutron stars. The EoS is the pressure $P$ as a function of energy density $\epsilon$, i.e, $P=P(\epsilon)$, while the $M-R$ curve is the inverse of the function $R=R(M)$, i.e., radius $R$ as a function of mass $M$.
#
# Load the energy density $\mathbf{E}$, pressure $\mathbf{P}$, mass $\mathbf{M}$, and radius $\mathbf{R}$ matrices. Check their dimensions.

# %%
ϵ = df.iloc[0:, 0:800:4]
p = df.iloc[0:, 1:800:4]
m = df.iloc[0:, 2:800:4]
r = df.iloc[0:, 3:800:4]

ϵ = np.array(ϵ, dtype=float)
p = np.array(p, dtype=float)
m = np.array(m, dtype=float)
r = np.array(r, dtype=float)

print("dim(ϵ) =", ϵ.shape[0], "x", ϵ.shape[1])
print("dim(P) =", p.shape[0], "x", p.shape[1])
print("dim(M) =", m.shape[0], "x", m.shape[1])
print("dim(R) =", r.shape[0], "x", r.shape[1])
# Out:
# dim(ϵ) = 5489 x 200
# dim(P) = 5489 x 200
# dim(M) = 5489 x 200
# dim(R) = 5489 x 200

# %% [markdown]
# Plot some randomly chosen $M-R$ curves and their corresponding EoS.

# %%
fig, ax = plt.subplots(1,2, figsize=(18,6))

ax[0].set_xlabel("Radius [$km$]")
ax[0].set_ylabel("Mass [$M_\odot$]")
ax[0].set_title("$M-R$ Curve")
ax[0].grid()
ax[1].set_xlabel("Energy Density [$M_\odot / km^3$]")
ax[1].set_ylabel("Pressure [$M_\odot / km^3$]")
ax[1].set_title("EoS")
ax[1].grid()

for j in range(10):
    i = np.random.choice(r.shape[0])
    xe = ϵ[i]
    yp = p[i]
    xr = r[i]
    ym = m[i]
    ax[0].plot(xr, ym)
    ax[1].plot(xe, yp)

# %% [markdown]
# Upon visual inspection, it appears that all cells in the four matrices are non-zeros. So, we keep all rows and columns of these matrices.
#
# ### 2. Convert units to match 3P and 4L data
#
# The pressure has unit $M_\odot/\mathrm{km}^3$ in this data, while it is $\mathrm{MeV/fm}^3$ in 3P and 4L data. Hence, we convert units of pressure (and energy density) from $M_\odot/\mathrm{km}^3$ to $\mathrm{MeV/fm}^3$. However, we leave mass and radius alone since they have the same units of $M_\odot$ and $\mathrm{km}$ as in the 3P/4L data, respectively.

# %%
M_sun = 1.989e30    # kg
c = 2.998e8         # m/s
E_sun = M_sun*c*c   # J
e = 1.6e-19         # C
km_to_fm = 1.0e18   # fm
J_to_MeV = 1.0e-6/e # MeV
ρ = E_sun * J_to_MeV / (km_to_fm)**3

Ed = np.zeros_like(ϵ)
Pr = np.zeros_like(p)
Ms = m
Rd = r

for i in range(ϵ.shape[0]):
    Ed[i] = ϵ[i] * ρ
    Pr[i] = p[i] * ρ

# %% [markdown]
# Plot some randomly chosen $M-R$ curves and their corresponding EoS or $P-\epsilon$ curves.

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].set_xlabel("Radius [$km$]")
ax[0].set_ylabel("Mass [$M_\odot$]")
ax[0].set_title("$M-R$ Curve")
ax[0].grid()
ax[1].set_xlabel("Energy Density [$MeV / fm^3$]")
ax[1].set_ylabel("Pressure [$MeV / fm^3$]")
ax[1].set_title("EoS")
ax[1].grid()

for j in range(5):
    i = np.random.choice(r.shape[0])
    xe = Ed[i]
    yp = Pr[i]
    xr = Rd[i]
    ym = Ms[i]
    ax[0].plot(xr, ym)
    ax[1].plot(xe, yp)

# %% [markdown]
# ### 5. Remove data with maximum mass $<2 M_\odot$
#
# The data contains EoS of neutron stars with maximum mass below $2M_\odot$. We remove such $M-R$ curves and their associated EoS.

# %%
E, P, M, R = [], [], [], []

for i in range(Ed.shape[0]):
    m_max = np.max(Ms[i])
    if not m_max < 2.0:
        E.append(Ed[i])
        P.append(Pr[i])
        M.append(Ms[i])
        R.append(Rd[i])

E = np.array(E)
P = np.array(P)
M = np.array(M)
R = np.array(R)

print("dim(ϵ) =", E.shape[0], "x", E.shape[1])
print("dim(P) =", P.shape[0], "x", P.shape[1])
print("dim(M) =", M.shape[0], "x", M.shape[1])
print("dim(R) =", R.shape[0], "x", R.shape[1])
# Out:
# dim(ϵ) = 551 x 200
# dim(P) = 551 x 200
# dim(M) = 551 x 200
# dim(R) = 551 x 200

# %% [markdown]
# ### 6. Rescale grid and interpolate/extrapolate points
#
# Unlike 3P and 4L data, the $P-\epsilon$ and $M-R$ curves are given as $(x, y)$ points, instead of simply $y=y(x)$ points. Thus the mapping is $\mathbb{R}^2 \to \mathbb{R}^2$, instead of $\mathbb{R} \to \mathbb{R}$. Such mapping goes beyond the scope of a deep-learning neural network. Moreover, the tidal data has grid size 200, while 3P and 4L data has 100.
#
# Therefore, we must reduce the grid size to 100 and interpolate pressure and mass points at the same grid points as in 3P and 4L.

# %%
def interp_eos(x, y):
    low = 0.3*197.327
    high = 10.0*197.327
    ed = np.linspace(low, high, 100)
    f_eos = interpolate.interp1d(x, y, kind='slinear', bounds_error=False, fill_value='extrapolate')
    pr = f_eos(ed)
    for i in range(len(pr)):
        if pr[i]<0.0:
            pr[i] = 0.0
    return pr

def interp_mrc(x, y):
    low = 0.2
    high = 3.0
    ms = np.linspace(low, high, 100)
    f_mrc = interpolate.interp1d(x, y, kind='nearest', bounds_error=False, fill_value='extrapolate')
    rd = f_mrc(ms)
    for i in range(len(rd)):
        if rd[i]<0.0:
            rd[i] = 0.0
    return rd

# %%
# Interpolate/extrapolate grid points
pr, rd = [], []

for i in range(E.shape[0]):
    pr.append(interp_eos(E[i], P[i]))
    rd.append(interp_mrc(M[i], R[i]))

pr = np.array(pr)
rd = np.array(rd)

print("dim(P) =", pr.shape[0], "x", pr.shape[1])
print("dim(R) =", rd.shape[0], "x", rd.shape[1])
# Out:
# dim(P) = 551 x 100
# dim(R) = 551 x 100

# %%
fig, ax = plt.subplots(2,2, figsize=(15,10))

ax[1,0].set_xlabel("Radius [$km$]")
ax[0,0].set_ylabel("Mass [$M_\odot$]")
ax[0,0].set_title("$M-R$ Curve")
ax[1,1].set_xlabel("Energy Density [$MeV / fm^3$]")
ax[0,1].set_ylabel("Pressure [$MeV / fm^3$]")
ax[0,1].set_title("EoS")
ax[0,0].grid()
ax[0,1].grid()
ax[1,0].grid()
ax[1,1].grid()

z = np.arange(100)

for j in range(10):
    i = np.random.choice(rd.shape[0])
    ax[0,0].plot(R[i], M[i])
    ax[0,1].plot(E[i], P[i])
    ax[1,0].plot(rd[i], z)
    ax[1,1].plot(pr[i])

# %% [markdown]
# ### 7. Readjust $M-R$ curves

# %%
rds, prs = [], []

for i in range(rd.shape[0]):
    ri = rd[i]
    r0 = ri[0]
    r1 = ri[-1]
    i0 = np.where(ri==r0)[0]
    i1 = np.where(ri==r1)[0]
    ri[i0] = np.max(r)
    ri[i1] = 0.0
    rds.append(ri)
    
rds = np.array(rds)
prs = pr

print("dim(P) =", prs.shape[0], "x", prs.shape[1])
print("dim(R) =", rds.shape[0], "x", rds.shape[1])
# Out:
# dim(P) = 551 x 100
# dim(R) = 551 x 100

# %%
# Recover the modified matrix rd
rd = []
for i in range(R.shape[0]):
    rd.append(interp_mrc(M[i], R[i]))
rd = np.array(rd)

# %%
fig, ax = plt.subplots(2,2, figsize=(15,10))

ax[1,0].set_xlabel("Radius [$km$]")
ax[0,0].set_ylabel("Mass [$M_\odot$]")
ax[0,0].set_title("$M-R$ Curve")
ax[1,1].set_xlabel("Energy Density [$MeV / fm^3$]")
ax[0,1].set_ylabel("Pressure [$MeV / fm^3$]")
ax[0,1].set_title("EoS")
ax[0,0].grid()
ax[0,1].grid()
ax[1,0].grid()
ax[1,1].grid()

z = np.arange(100)

for j in range(10):
    i = np.random.choice(rd.shape[0])
    ax[0,0].plot(rd[i], z)
    ax[0,1].plot(pr[i])
    ax[1,0].plot(rds[i], z)
    ax[1,1].plot(prs[i])

# %%
rad = np.zeros((rds.shape[0], 90))
rad[:, 0] = np.max(r)
rad[:, 1:90] = rds[:, 11:100]
x0 = np.zeros(90)
x0[1:90] = np.arange(11,100)
mrc = []

for i in range(rad.shape[0]):
    f = interpolate.interp1d(x0, rad[i], kind='slinear', bounds_error=False, fill_value='extrapolate')
    x1 = np.arange(100)
    y = f(x1)
    mrc.append(y)

mrc = np.array(mrc)
eos = prs

print("dim(P) =", eos.shape[0], "x", eos.shape[1])
print("dim(R) =", mrc.shape[0], "x", mrc.shape[1])
# Out:
# dim(P) = 551 x 100
# dim(R) = 551 x 100

# %%
fig, ax = plt.subplots(2,2, figsize=(15,10))

ax[1,0].set_xlabel("Radius [$km$]")
ax[0,0].set_ylabel("Mass [$M_\odot$]")
ax[0,0].set_title("$M-R$ Curve")
ax[1,1].set_ylabel("Pressure [$MeV / fm^3$]")
ax[0,1].set_ylabel("Pressure [$MeV / fm^3$]")
ax[0,1].set_title("EoS")
ax[0,0].grid()
ax[0,1].grid()
ax[1,0].grid()
ax[1,1].grid()

z = np.arange(100)

for j in range(10):
    i = np.random.choice(rd.shape[0])
    ax[0,0].plot(rds[i], z)
    ax[0,1].plot(prs[i])
    ax[1,0].plot(mrc[i], z)
    ax[1,1].plot(eos[i])

# %% [markdown]
# ### 8. Write the processed data to files
#
# Finally, the data is ready to be used for training neural networks. We save the energy density, pressure, mass, and radius matrices into text files.

# %%
np.savetxt("mrc_td.txt", mrc)
np.savetxt("eos_td.txt", eos)
